# %%
#菲姐-全部爬出來, 內容很不一致, 但仍建議用此方法爬出,在手工整理 ＃377筆
import requests
from bs4 import BeautifulSoup
page_format = "http://www.italian-lifestore.com.tw/recipe.php?SearchRecipeVideoCateID=&SearchKey=&SearchType1=&SearchType2=&Page=%d"

recipe_file = open("sis_recipe_list.txt", 'w')
for page in range(0,38): 
    recipe_list = requests.get(page_format%(page)) 
    recipe_response = recipe_list.text
    soup = BeautifulSoup(recipe_response)
    recipe_table = soup.select(".food")[0]
    recipe_rows = recipe_table.select('.clearfix')
    for recipe_row in recipe_rows:
        links = [tag['href'] for tag in recipe_row.select('a')] 
        link_href = "http://www.italian-lifestore.com.tw/" + links[0] 
        recipe_file.write(link_href + "\n") 
recipe_file.close()

#把每頁菜單的食材和步驟寫入
recipe_file = open("sis_recipe_list.txt", 'r')
for line in recipe_file.readlines(): 
    pagelink = line.strip() 
    request_get = requests.get(pagelink) 
    request_get.encoding = 'utf-8'
    soup = BeautifulSoup(request_get.text.encode('utf-8')) 
    try:
        sis1_ingredients = open('sis1_ingredients.txt','a')
        ingredientsList = [] 
        ingredients = soup.select(".recipe-tBox")[0].text.strip()
        a = ''.join(ingredients.split('-'))
        b = ','.join(a.split())
        ingredientsList.append(b)

        for i in ingredientsList:
            sis1_ingredients.write((i+',').encode('utf-8')) 
        sis1_ingredients.write('\n')    
    except:
        pass
sis1_ingredients.close()
recipe_file.close()

# %%
#How to replace “烹飪步驟” with the content in front of first comma? = Title name.
in_file = open('sis1_ingredients.txt','r')
out_file_ingredients = open('sis2_ingredients.txt','w')
ingredients = []
for line in in_file.readlines():
    ingredient = line.split("烹飪步驟,")[0]
    ingredients.append(ingredient)
for i in ingredients:    
    out_file_ingredients.write(i+'\n')
out_file_ingredients.close()
in_file.close()

in_file = open('sis1_ingredients.txt','r')
out_file_steps = open('sis2_steps.txt','w')
steps = []
for line in in_file.readlines():
    step = line.split("烹飪步驟,")[1]
    print step
    steps.append(step)
for i in steps:    
    out_file_steps.write(i+'\n')  
out_file_steps.close()
in_file.close()

in_file = open('sis1_ingredients.txt','r')
out_file_titles = open('sis2_titles.txt','w')
titles = []
for line in in_file.readlines():
    title = line.split(",")[0]
    titles.append(title)
for i in ingredients:    
    out_file_titles.write(i+'\n')  
out_file_titles.close()    
in_file.close()
# Out:
# 1.先將干貝泡軟撕成絲，菜頭去皮切細絲備用。,2.在來米粉慢慢加水拌勻待用。,3.備平鍋加熱，將蘿蔔絲放入鍋中煮熟後倒入在來米粉中，再將干貝絲也全放入，加入少許鹽及胡椒粉調味。,4.備蒸籠，內放入大棉布，將調味好的在來米粉全倒入，再將蒸籠放入快鍋中，快鍋內加少許水，蓋上鍋蓋開大火煮開至發出唧唧聲後轉小火煮30分鐘既可關火排氣。,5.起鍋放涼後，可將蘿蔔糕切片放入平鍋中煎至焦黃食用,
#
# 1.備羅伯鍋加入1/3水加熱，將牛腱放入川燙一下取出備用。,2.備快鍋加入1/3水煮開，將牛腱、八角、蔥段、薑片等材料入鍋中，再加入少許酒提味後，蓋上鍋蓋煮滾至發出唧唧聲後轉小火煮25分鐘後關火排氣。,3.將冬粉泡軟備用。,4.再備湯鍋加入少許油加熱，擺入洋蔥丁爆香，再加入咖哩粉炒香後，倒入牛肉清湯、加入油豆腐煮滾，再將牛肉切片放入，再加少許鹽調味，最後將冬粉也加入煮滾。,5.起鍋盛盤時，再擺上蒜苗絲提味，即可上桌享受。,
#
# 1.牛腩川燙過。,2.將1置於快鍋中加水、八角唧唧聲後煮12分鐘，加少許鹽。,3.麵粉加水攪拌成稠狀，控一小匙一小匙放入牛肉湯汁中。,
#
# 1.備羅伯鍋加入1/3水煮開，將排骨放入川燙一下取出備用。,2.將乾魷魚泡軟，剪成條狀待用。,3.備內鍋，將雞腿剁塊擺入，加入辣椒末、蔥段，再將少許蝦醬、魚露、醬油及水調勻後淋上備用。,4.備快鍋加入1/3水煮開，將筍去皮切片擺入，再加入排骨、魷魚入鍋中，置入三角架擺上內鍋，蓋上鍋蓋煮滾至發出唧唧聲後，轉小火煮7分鐘後關火排氣。,4.湯起鍋時再加入少許鹽、酒調味，即可上餐桌食用。,
#
# 1.備羅伯鍋加入1/3水煮開，將肋排放入川燙取出備用。,2.備快鍋加入1/3水著開，將紅蘿蔔、白蘿蔔刨皮切塊入鍋中，再將肋排、南北杏、黑棗、陳皮全加入，蓋上鍋蓋煮滾至發出唧唧聲後轉小火煮15分鐘後關火排氣。,3.湯起鍋時再加入少許鹽、酒調味既可上餐桌食用。,
#
# 湯鍋加入3/1水煮開，將餛飩放入煮熟後取出置碗中，再將xo醬加入攪拌入味既可盛磐食用。,將湯鍋中的湯汁再煮開，將小白菜切段放入，再將蛋置碗中打散也加入煮開，再加入少許鹽調味既可。,湯起鍋前可加入少許海苔片和蔥花調味。,
#
# 1.先將茄子切大片、洋蔥切絲、蒜頭切末備用。,2.備平鍋倒入少許油加熱，將蒜末放入鍋中爆香，再將茄子及洋蔥絲全擺入，加入少許水後蓋上鍋蓋燜煮至熟透。,3.起鍋時再加入少許醬油、酒、XO醬調味拌勻後，再加入蔥花及九層塔提味既可上桌。,
#
# 1.備小湯鍋加水煮開，將鮮百合一片片剝開後，川燙一下，取出備用。,2.蝦仁拭乾加入太白粉、薑片攪拌後備用。,3.青椒去仔切小片待用。,4.備平鍋倒入少許油加熱，將蝦仁先放入鍋中拌炒，再加入xo,醬拌勻，加入青椒、百合及少許酒、鹽、醬油調味攪拌，既可盛盤上餐桌。,
#
# 1.備羅伯鍋加3/1水煮開，先將湯圓入鍋煮熟備用。,2.備湯鍋加入3/1水煮開，加入老薑、桂圓肉及紅糖燜煮一下後再加入湯圓既成美味的桂圓甜湯圓。,3.再備湯鍋倒入少許油加熱，先將肉絲、香菇絲、蝦米、蔥末入鍋中爆香，再加入少許胡椒粉、醬油調味後盛出備用。,4.湯鍋中再倒入3/1水煮開，加入湯圓、炒好的材料及少許鹽、醬油調味，起鍋時再加入茼萵、芹菜末、紅蔥酥提味既可盛盤上桌享受美味的鹹湯圓。,
#
# 1.先將紅、白蘿蔔刨皮切薄片備用。,2.將肉切薄片加入蒜片、辣椒末及少許太白粉、醬油調味備用。,3.備平鍋倒入少許油加熱，先將花椒放入爆香後撈出，放入肉片拌炒，再加入紅、白蘿蔔片、宮保、大白菜及高湯及少許水,調味後蓋上鍋蓋燜煮一下既可。,4.起鍋前再加入少許鹽、酒既可盛盤上餐桌。,
#
# 1.先將泰國蝦從背身剪開，備用。,2.備平鍋倒入少許麻油加熱，將薑、蔥、蒜頭、辣椒全切末放入鍋中爆香，再把泰國蝦全放入鍋中爆炒，加入少許糖、酒、醬油及醬油膏調味後蓋上鍋蓋燜煮約1分鐘。,3.掀鍋蓋，既可起鍋，既成一道健康美味的美食,
#
# 1.先將綠竹筍去皮切滾刀，乾香菇泡軟備用。,2.備小湯鍋開小火加熱，加入麻油爆香，將薑切片也放入鍋中爆香，再將辣椒段也放入拌炒一下，再將筍全放入鍋中蓋上鍋蓋燜煮。,3.掀鍋蓋再加入少許素蠔油、糖、醬油及水調味後再蓋上鍋蓋燜煮至收湯汁既可。,4.起鍋前加入九層塔提味既可上餐桌,
#
# 1.先將雞肉切塊備用。,2.備平鍋倒入少許黑麻油加熱，將薑片放入爆香後，再加入蔥段、蒜片爆香，再將雞塊、辣椒段全加入鍋中後，再蓋上鍋蓋燜煮即可。,3.起鍋前加入少許酒、醬油膏、醬油調味，既可盛盤上餐桌。,
#
# 1.石斑角身上劃兩刀加入蔥段、酒及薑片，蒸之前再倒一些魚露、糖、蠔油，放入2枝竹筷將魚架空。,2.平底鍋放半鍋水，開中火燒開，放入三角架將魚放入鍋中，蓋上鍋蓋蒸8~10分鐘。,3.蒸好的魚換裝入一個大盤中，灑下蔥絲、薑絲、紅辣椒絲。,4.小湯鍋燒點油，淋在蒸好的魚身上即可。,
#
# 1.備羅伯鍋加入3/1水燒開，將高麗菜心放入再倒入少許油川燙一下取出圍至盤邊待用。,2.將杏鮑菇切片，鴻喜菇撕開，鮮香菇對切待用。,3.備平鍋倒入少許油加熱，將薑切片放擩入鍋中爆香，再將所有的杏鮑菇、鴻喜菇、洋菇、鮮香菇全放入鍋中拌炒一下後蓋鍋蓋燜煮一下既可。,4.起鍋前加入胡椒粉及蠔油調味再加入太白水芶芡既可盛盤。,5.最後再將玉米粒擺入高麗菜心上既成美味可口的素食佳餚。,
#
# 1.備羅伯鍋加入1/3水煮開，將細拉麵放入川燙至熟撈出盛盤。,2.先將肉切絲加入少許沙拉油、太白粉、醬油及蔥段攪拌備用。,3.將香菇、木耳、紅蘿蔔全切絲備用。,4.備平鍋倒入少許油加熱，將肉絲入鍋拌炒，再加入香菇、木耳、紅蘿蔔絲拌炒，再倒入高湯及少許蠔油調味後蓋上鍋蓋燜煮。,5.最後加入豆芽菜及青江菜拌炒，少許醬油提味，太白粉勾芡後淋上麵條即可上餐桌。,
#
# 1.九尾草放ROBO鍋中燉煮20分鐘。,2.將1之湯汁倒入快鍋中，放矢雞肉塊、枸杞子、紅棗(適量)、米酒，唧唧聲後煮3分鐘。,
#
# 1.先將平鍋倒入少許油加熱，將魚身畫刀放入鍋中煎一下，再放入薑片爆香去腥後蓋鍋蓋。,2.掀鍋蓋，等魚身煎至金黃色後，翻面再蓋鍋蓋。,3.掀鍋蓋，等魚身也煎至金黃既可盛盤，使用前可滴少許檸檬汁,
#
# 1.先將薑切片加入牛肉絲再倒入少許醬油稍醃一下入味備用。,2.將青椒、黃椒、紅椒、洋蔥全切絲備用。,3.備平鍋，倒入少許油加熱，將蔥切段放入鍋中爆香，再將牛肉絲放入拌炒一下既可。,4.將所有的青椒絲、紅椒絲、黃椒絲、洋蔥絲全放進快鍋中拌炒一下後蓋上鍋蓋。,5.掀鍋蓋加入少許酒及鹽調味既可上桌食用,
#
# 1.先將雞胸肉切塊，加入少許太白粉、沙拉油、醬油、蒜片、蔥段及辣椒段拌勻備用。,2.備湯鍋加入少許油加熱，先將雞肉材料入鍋中拌炒，加入少許辣豆瓣醬調味後，再加少許糖、醬油、酒提味。,3.起鍋前再將青、紅、黃椒片擺入蓋上鍋蓋燜煮一下既可盛盤上餐桌享受。,
#
# 1.先將竹筍去皮切絲、紅、黃椒去仔切絲、百合剝片洗淨備用。,2.將蘋果刨皮切絲泡鹽水備用。,3.備平鍋倒入少許油加熱，將筍絲、紅、黃椒絲、蘋果絲、百合全加入鍋中後蓋上鍋蓋燜煮約1分鐘既可。,4.起鍋前再加入少許鹽及枸杞調味既可盛盤上餐桌享用。,
#
# 1.雞腿切塊川燙洗淨備用。,2.將水煮滾加入所有材料，小火燉煮25分鐘，最後加入米酒塩調味即可。,
#
# 1.先將薑、辣椒切絲、蒜頭切片、黃椒切塊、蔥切段、四季豆切斜刀備用。,2.開火熱油鍋、將魚背劃上刀紋，魚身擦乾後放入平鍋中蓋上鍋蓋、轉小火煎3分鐘、打開鍋蓋將魚翻面、放入蔥段、薑絲再蓋上鍋蓋關火燜煎。,3.煎3分鐘後打開鍋蓋加入四季豆、黃椒、蓮子（熟煮好的蓮子）、少許鹽、醬油再蓋上鍋蓋煮３分鐘、起鍋前加入醋、胡椒粉即可食用。,
#
# 起油鍋，爆香薑片，放入花椰菜、青花菜、蕃茄塊加點水，煮至熟。,
#
# 1.備平鍋倒入少許油加熱，將豆腐拭乾切大片後，擺入鍋中，蓋上鍋蓋煎至金黃即可。,2.掀蓋後翻面，再將蕃茄切片、木耳切絲、筍去殼切片及蔥段全放入鍋中，加入少許醬油、蠔油、糖、酒調味及少許水後蓋上鍋蓋燜煮即可。,3.起鍋前加入少許太白水勾芡既可上餐桌。,
#
# 1.先將乾香菇泡軟切絲，蝦米泡水備用。,2.備羅伯鍋倒入3/1水燒開，將豬腳丁、排骨川燙一下取出待用。,3.備小湯鍋加入2/1水煮開，將筍絲放入鍋中煮，將其鹹味去除既可備用。,4.備快鍋加入2/1水煮開，將豬腳丁、排骨、香菇絲、蝦米、筍絲芋頭、蒜頭、白菜等所有材料全放入快鍋中，蓋上鍋蓋開大火煮開至發出唧唧聲後轉小火煮15分鐘既可關火排氣。,5.起鍋前放入少許胡椒粉、鹽及酒調味既可盛盤上餐桌食用。,
#
# 1.備快鍋倒入黑麻油加熱，將老薑切片擺入爆香，再將去皮雞肉也加入後先蓋上普通鍋蓋燜煮約2分鐘，倒入米酒蓋上材料，再加入少許糖調味，蓋上快鍋鍋蓋，轉中火煮開至發出唧唧聲後轉小火煮5分鐘既可關火排氣。,br>,2.備砂鍋加熱，將高麗菜擺入鍋中，再倒入麻油雞燜煮一下既可。,3.備羅伯特鍋加入3/1水煮開，將麵線放入燙熟後撈出，加入麻油、老薑片拌勻既可全部放上餐桌。,
#
# 1.先將雞腿去骨，加入胡椒粉、醬油調味稍醃一下備用。,2.備平鍋倒入約7分滿的油加熱，將醃好的雞腿先沾上蛋汁、再沾上麵粉、再裹上一層麵包屑後放進鍋中炸至金黃既可盛盤備用。,3.再備容器，將沙拉醬、原味優格、黃芥末醬、巴西里加入調味攪拌均勻後淋上既可上餐桌。,
#
# 鍋中加水，將八寶粥料放入水中，以中火煮至發出笛音聲，改小火計時15分鐘。,關火，關上氣閥，燜15分鐘，開蓋放入紅糖拌勻即可。,
#
# 1.蛤蜊泡水去砂、冬瓜去皮切塊、嫩薑洗淨切絲備用。,2.燉鍋放入冬瓜及水半鍋以中火煮滾，改成小火燉煮8分鐘。,3,打開鍋蓋加入蛤蜊、嫩薑絲及酒，煮到蛤蜊打開，最後再加入塩來調味，起鍋前放入九層塔裝飾即可上桌。,
#
# 1.先將冬菇泡軟，再將紅、白蘿蔔刨皮，刻花切片，薑切片備用。,2.備平鍋倒入少許油加熱，將豆腐去老皮切塊後，擺滿鍋中乾煎至兩面金黃，再將冬菇絲、紅、白蘿蔔片、薑片加入，加少許醬油、素蠔油、糖及少許水調味後，蓋上鍋蓋燜燒。,3.起鍋前再加入少許香油及胡椒粉提味既可盛出上餐桌。,
#
# 1.排骨拍鬆後切段，拌入醃料待10分鐘。,2.子薑切粒後1/2茶匙鹽拌勻待15分鐘，然後沖淨。,3,排骨沾上蛋液及麵粉，放入中火油內炸熟，盛盤。,4,燒2湯匙油爆炒子薑粒，話梅，辣椒及蒜蓉，倒下芡沖煮片刻。,5,最後拌入生粉水勾芡，淋於雞上即可。,
#
# 1.先將錫箔紙撕2大張，將蒜頭切末加入，再放少許奶油後將美力菇切片、金針菇、洋菇、鮮香菇等所有材料全擺入，再加入少許鹽及酒調味後包緊。,2.備平鍋開中火加熱，將材料擺入，蓋上鍋蓋開中火乾烤約8分鐘既可關火盛盤上餐桌食用。,
#
# 1.洋蔥切丁、地瓜切塊備用。,2.中火預熱鍋子，放入橄欖油加入洋蔥炒至透明。,3,加入雞肉和薑末拌炒一下，加入所有混合香料再加入水和蜂蜜拌勻。,4,加入地瓜丁及葡萄乾，蓋上鍋蓋煮滾後改小火燉煮，中間可隨時開蓋攪拌，計時約30分鐘即可。,
#
# 1.備小湯鍋加入3/1水燒開，將半天筍放入鍋內川燙一下取出備用。,2.再將牛肉切絲，加入少許醬油、糖、太白粉調味攪拌稍醃一下。,3.備平鍋，倒入少許油加熱，將蔥、辣椒切段放入鍋內爆香，再將牛肉絲放入鍋內拌炒一下，最後將川燙好的半天筍也放入鍋中拌炒均勻至熟既可起鍋盛盤上餐桌。,
#
# 1.先將雞肉切小丁，加入蒜片、蔥段、少許太白粉、沙拉油攪拌調味備用。,2.備平鍋倒入少許油加熱，將花椒放入爆香後撈出花椒粒，再放入雞丁拌炒，再將乾辣椒全加入蓋上鍋蓋約1分鐘既可起鍋上,餐桌。,
#
# 先把南瓜切碎，洋蔥切絲,熱2湯匙橄欖油和30克牛油在鍋中，放入洋蔥,南瓜,栗子和原粒蒜頭（不需去皮），蓋好煮3分鐘,加入白酒，用湯匙輕輕在煮鍋內攪拌直水份蒸發，加入清雞湯，以湯計完全覆蓋所有材料（在煮滾湯汁時水份容易蒸發，可再慢慢加入少許雞湯，用同樣火溫煮8分鐘,熄火，除去蒜頭，把剩餘的牛油和巴爾馬起士加入煮鍋中，拌勻．,醃肉片放在平底鍋內煎至金黃色（不用加油）煮好後用廚房紙巾抹乾，備用．,把貝殼粉放在餐盤上，每碟加入兩片醃肉，即完成．,
#
# 1.南瓜去皮、去籽、加水煮10分鐘，在用打蛋器打成泥。,2.將南瓜尼加適量的水，海鮮料理包煮滾後，在灑上鹽，胡椒粉即可。,
#
# 1.備羅伯鍋加入3/1水煮開，將拉麵入鍋煮熟後盛盤備用。,2.將乾香菇泡軟切絲、杏鮑菇切絲、芹菜切段、薑片、南瓜去皮去仔切薄片備用。,3.備平鍋倒入少許油加熟，先將薑片爆香，將材料全入鍋中拌炒一下，加入少許水後蓋上鍋蓋燜煮至熟既可。,4.起鍋前加入少許醬油、鹽、胡椒粉調味，再加芹菜段拌炒後淋上麵條既可上餐桌。,
#
# 先將紅蟳清洗乾淨,以中火預熱，至水珠撒入成滾動狀，轉成小火，放入紅蟳蓋上鍋蓋烤5分鐘，加入少許米酒再烤5分鐘，待紅蟳轉成紅色即可。,
#
# 1.先將鮭魚加入少許鹽、酒稍醃一下後擦乾水份備用。,2.將鳳梨片、青椒、紅椒全切小丁備用。,3.備平鍋加熱,(不倒油)，將鮭魚入鍋中蓋上鍋蓋，乾煎至二面金黃後盛盤備用。,4.備小湯鍋，倒入鳳梨汁，加入鳳梨丁、青、紅椒丁，再加少許鹽調味後煮滾，起鍋前再加入太白水勾芡淋入鮭魚既可上餐桌。,
#
# 1.先將蘆筍去皮切段、薑切片、辣椒切段備用。,2.備平鍋倒入少許油加熱，先將薑片、蘆筍、辣椒、吻仔魚及少許水後蓋上鍋蓋燜煮一下既可。,3.起鍋前加入少許鹽及酒調味既可盛盤上餐桌。,
#
# 1.起油鍋，海臭蟲切塊放入，放入薑片，煮至熟。2.味增用水調稀，倒入1.再加入雞蛋豆腐(切塊)、蔥段，煮至熟。3.盤中放入油條(切塊)，將2料倒在其上。,
#
# 將油魚洗淨擦乾，再將味噌、味霖及糖拌勻塗抹在魚的表面冰至冰箱冷藏，醃置一天的時間。,取出已醃置好的魚將表面的醬汁略洗並擦乾。,燒烤鍋以中火預熱，至水珠撒入成滾動狀，轉成小火，將魚放入鍋中蓋上鍋蓋，烤56分鐘翻面煎烤至二面成金黃色。,上桌前擠上一些檸檬汁風味更棒！,
#
# 1.後腿肉切菱形塊狀，加米酒、鹽拌均勻，沾太白粉，將太白粉與肉用手捏緊，湯鍋倒半鍋油燒熱，將肉入鍋炸至金黃色撈起。,2.平底鍋放進A，燒開成濃稠狀，將炸好的肉及鳳梨片倒入拌均勻，起鍋後撒上芝麻即可。,
#
# 1.先將雞胸肉切絲加入沙拉油、太白粉、蒜片、辣椒片調味攪拌備用。,2.綠竹筍去殼切絲備用。,3.備平鍋倒入少許油加熱，將雞肉絲放入鍋中拌炒，再加入筍,絲、辣椒一起拌炒均勻，加入少許水後蓋上鍋蓋燜熟既可。,4.起鍋前加入咖哩粉及少許鹽、糖及酒調味攪拌均勻，再淋入椰漿提味，最後起鍋時再加入九層塔提味既可上餐桌。,
#
# 1.先將馬鈴薯去皮切絲、紅蘿蔔薑切絲備用。,2.備平鍋倒入少許牛油加熱，先將馬鈴薯絲擺入及少許水、椰漿咖哩粉調味後蓋上鍋蓋燜煮一下，再加入紅蘿蔔絲及毛豆仁拌炒，加少許鹽、酒及糖調味既可盛盤上餐桌。,
#
# 1.豬肉切片，用太白粉、油、酒精稍醃一下。2.起油鍋，將蒜頭、酒、拌炒，再加入已燙熱的紅蘿蔔片、馬鈴薯片、九層塔，起鍋前灑點檸檬汁。,
#
# 1.先將蟹洗淨切塊，再裹上麵粉備用。,2.備平鍋加熱，將蟹全放入鍋中煎至焦黃計既可先倒出盤中備用。,3.將蒜頭、薑切末放入鍋中爆香，倒入牛奶、椰漿，加入咖哩粉攪拌一下，再將煎熟的螃蟹倒入鍋中燜煮約23分鐘後加入少許紅椒粉及蛋汁和少許酒後，再燜煮約12分鐘既可。,4.起鍋前加入芹菜末既可上桌食用。,
#
# 1.先將里肌肉切厚片用肉槌拍平，加入少許醬油、糖、蒜末調味稍醃一下備用。,2.備平鍋倒入3/1油加熱，將蛋打散，再將調理好的豬排沾上蛋汁及地瓜粉後放入油鍋中炸至金黃後取出盛盤待用。,3.備小湯鍋倒入少許油加熱，將洋蔥切末放入鍋中爆炒，再倒入咖哩粉攪拌，加入少許麵粉拌炒均勻後，加入少許水芶芡既可。,4.最後將咖哩汁淋上豬排上既成美味的咖哩豬排。,
#
# 白米洗淨備用、紅蘿蔔、馬鈴薯切小塊、洋蔥切丁、去骨雞腿切小塊備用。,準備一個小內鍋，放入白米及水。,中空鍋中放入奶油開中火，加入洋蔥炒至洋蔥變軟，再放入雞腿、紅蘿蔔、馬鈴薯加水與食材一樣高，再放入咖哩塊。,擺入三角架及小內鍋，蓋上鍋蓋，中火煮至發出笛音聲改小火，計時6分鐘，關火，關上氣閥，燜10分鐘，即可成為一鍋二菜的做法。,
#
# 1.先將雞胸肉切小丁，加入蒜片、蔥丁、薑末、辣椒末及少許太白粉、沙拉油、醬油攪拌調味備用。,2.備平鍋倒入少許油加熱，將雞丁放入拌炒，再加入豆瓣醬、糖、醬油、蠔油攪拌調味。,3.再將高麗菜切丁全擺入鍋中，再加入少許酒提香，起鍋前再加入花生粒，即可盛盤上餐桌。,
#
# 1.備羅伯鍋加入3/1水煮開，將排骨放入川燙一下取出待用。,2.備快鍋加入3/1水煮開，將蓮藕去皮切片，淮山、菜頭去皮切大塊，蕃茄切塊後全擺入鍋中後，蓋上鍋蓋開中火煮開至發出唧唧聲後轉小火煮15分鐘既可關火排氣。,3.起鍋時再加入少許鹽調味既可上餐桌。,
#
# 1.先將熟五花肉切片，豆干切斜片、青椒切小丁、蒜頭切末備用。,2.備平鍋加入少許油加熱後轉小火，將五花肉片放入鍋中爆炒至焦，再將蒜末、豆干放入拌炒一下後，再加入青椒丁後，加入少許辣椒醬、酒釀、糖、鹽及醬油調味後拌炒均勻。,3.起鍋時加入少許酒調味，再加入芹菜段既可盛盤上餐桌。,
#
# 1.牛肉絲以太白粉、醬油、蔥段稍微拌一下，放入平底鍋中炒，倒入蛋液，盛起。,2.原平底鍋中倒入米飯，稍微炒一下，加入洋蔥絲、青椒絲、辣椒丁，及1料再拌炒一下即可。,
#
# 1.先將洋蔥、西洋芹、馬鈴薯、蕃茄、高麗菜切丁備用。,2.中火熱鍋倒入油爆香洋蔥，再加入西洋芹、馬鈴薯、高麗菜、蕃茄及高湯煮滾改小火燉煮15分鐘。,3,最後加入蕃茄醬拌勻煮滾後熄火並調味料即可。,
#
# 地瓜切塊、梅花肉切片醃蠔油與糖約15分鐘，再沾上蒸肉粉備用。,備一個小內鍋，先放入地瓜塊再擺入梅花肉片。,中空鍋中加水，放入三角架再放小內鍋，蓋上鍋蓋，以中火煮至發出笛音聲改小火，計時20分鐘，關火，關上氣閥，燜10分鐘即可。,
#
# 1.備羅伯鍋加3/1水燒開，將義大利麵放入，加入少許鹽提味，煮12分鐘後取出備用。,2.備平鍋倒入少許油加熱，將蒜頭、洋蔥切末放入鍋中爆香，再將培根切末加入煎一下，再將蝦仁也放入煎熟既可。,3.將麵條取出倒入平鍋中攪拌，加入墨魚醬及少許白酒、胡椒粉調味攪拌既可起鍋上餐桌。,
#
# 1.將地瓜、馬鈴薯、蕃茄、紫洋蔥及雞腿切成塊備用。,2.以中火熱鍋倒入1大匙橄欖油，放入薑末、紫洋蔥爆香，接著放入雞腿略炒再加地瓜、馬鈴薯、蕃茄及調味料拌勻，加入半碗水後蓋上鍋蓋，轉成小火燜煮。,3,中途可打開鍋蓋均勻攪拌，並加入棕櫚糖燜煮約30分鐘。,
#
# 將山芋頭洗淨備用。,以中火預熱，至水珠撒入成滾動狀，轉成小火，舖上烘培紙再擺入山芋頭灑上塩，蓋上鍋蓋烤25分鐘即可,
#
# 明蝦先醃米酒、塩約15分鐘。,以中火預熱，至水珠撒入成滾動狀，轉成小火，放入明蝦烤至香味出來變色翻面，第二面同樣烤至香味出來即可。,
#
# 1.先將墨魚切一圈圈，九層塔切末備用。,2.備羅伯鍋加入3/1水煮開，加少許鹽，再將黑魚麵入鍋煮十二分鐘撈出備用。,3.備平鍋倒入少許橄欖油加熱，將蒜末入鍋爆香，再加入黑魚拌炒，加少許鹽、鮮油、白酒、巴西里、九層塔末調味拌炒後將麵條入鍋拌勻既可。,4.起鍋前再加少許起司粉提味既可盛盤上桌。,
#
# 1.備小湯鍋加入2/1水煮開，將柴魚放入敖成高湯備用。,2.將牛蒡去皮刨絲放入鹽水中備用。,3.備平鍋加熱，將牛油放入，再將洋蔥切絲及牛蒡絲全部放入拌炒均勻，倒入柴魚高湯後，將豆腐切塊擺入，再將鮮香菇、金針菇、白菜全放入鍋中煮滾，加少許淡醬油、酒、糖調味既可。,4.最後再將沙朗牛肉片放入鍋內川燙食用，可邊煮邊吃。,
#
# 1.先將蕃茄、小黃瓜、生菜切片、紅椒、黃椒切條全泡入冰水中備用。,2.備湯鍋加水煮開，先將蘆筍切段放入川燙一下取出泡入冰水中。,3.再將透抽切片放入鍋中川燙一下取出泡入冰水中。,4.備大碗公，將所有材料撈出濾乾放進，加入少許橄欖油、義大利醋調味入味既可盛盤上餐桌。,
#
# 1.備湯鍋加入高湯一瓶及3/1水煮開，將菜頭、紅蘿蔔刨皮切丁，入鍋中，再將乾香菇泡軟切丁也入鍋，蓋上鍋蓋燜煮一下既可。,2.備羅伯鍋加入3/1水煮開，將拉麵入鍋中燙熟取出備用。,3.湯煮滾後加入少許醬油、胡椒粉、鹽、烏醋調味拌勻再淋上太白水勾芡既可。,4.最後再將蝦仁入鍋煮熟淋入蛋汁攪拌均勻，起鍋前再將麵條擺入，灑上少許香菜提味既可盛盤入菜。,
#
# 1.備平鍋倒入七分滿的水煮開，擺上蒸籠後，再將大閘蟹連草繩一同洗淨，擺滿鍋中後，蓋上鍋蓋，轉中火蒸12分鐘既可盛盤上餐桌食用。,
#
# 備一個調理盆，將A材料放入拌勻，成為麵糊。,燒烤鍋倒入少許的油預熱，待到油紋出現改小火，倒入麵糊蓋上鍋蓋，待鍋邊冒水蒸氣翻面。,第二面煎一下，最後表面在塗上日式醬油，擠上沙拉，再擺上柴魚片即可。,
#
# 1.先將魚片去骨切厚片一片一片背用。,2.備蒸盤，先將一片魚片擺入、再擺入天麻、川芎、茯苓各一片後再重覆擺入至擺滿止，灑上蔥段，加入少許酒、醬油、鹽調味待用。,3.備平鍋加入1/2水煮開，擺入架子放進蒸盤，蓋上鍋蓋蒸煮5,分鐘既可關火盛出。,4.最後再將蔥段取出，再灑上蔥花及胡椒粉提香，即可上餐桌。,
#
# 1.先將牛肉切條加入薑片、辣椒末調味備用。,2.將奇異果去皮切條備用。,3.備平鍋倒入少許油加熱，將牛肉放入爆炒，再將奇異果全部放入拌炒均勻，倒入少許酒及醬油調味拌炒一下既可關火上餐桌食用。,
#
# 1.先將魚片切斜片，加入少許酒稍醃一下，裹上太白粉與麵粉混合之沾粉待用。,2.再將奇異果去皮切片擺盤裝飾備用。,3.備平鍋倒入少許油加熱，先將魚片一片片擺入鍋中蓋上鍋蓋煎至金黃，再翻面煎至金黃既可先盛盤備用。,4.再備湯鍋加入高湯加熱，將奇異鍋去皮切丁、小蕃茄切丁全加入鍋中攪拌，再加入少許鹽、胡椒粉、酒調味及太白粉芶芡後淋上魚片上既可上餐桌。,
#
# 玉米洗淨對中切。,以鋁箔紙包入玉米及奶油備用。,以中火預熱，至水珠撒入成滾動狀，轉成小火，將已包好的玉米放入，蓋上鍋蓋計時5分鐘，翻面再烤4分鐘即可。,
#
# 1.備湯鍋倒入牛奶約500cc加熱，加入奶酪粉(2包)及鮮奶油慢慢攪拌既可。,2.備模型道具，倒入糖漿，再將煮好的奶酪倒入模型中待涼既,可，置入冰箱風味更加。,
#
# 1.先將大白菜、紅蘿蔔、鮮香菇、冬筍、干貝全切絲備用。,2.將蟹腳加入少許酒醃一下沾乾後過油備用。,3.備湯鍋加入3/1水及高湯煮開，先將白菜絲、紅蘿蔔絲、筍絲入鍋煮熟，再加入鮮香菇絲及金針菇煮熟後先加少許醬油、胡椒粉、酒調味，太白粉勾芡既可。,4.最後再入干貝、蟹腳煮熟，起鍋前再加少許烏醋及香菜提味既可盛盤上餐桌。,
#
# 1.先將豆腐、紅蘿蔔、香菇泡軟、鱈魚全切丁備用。,2.備湯鍋倒入水及高湯加熱，先將豆腐、香菇丁入鍋中煮開。,3.再加入鱈魚、紅蘿蔔丁、金針菇，加少許鹽、醬油調味後，在,加太白水勾芡。,4.起鍋前再淋上蛋汁及少許酒調味既可盛盤上餐桌。,
#
# 1.平底鍋倒油加熱2分鐘，把材料陸續放入炒，加入A料及調味料，起鍋前再放入芹菜。,2.最後灑些胡椒粉炒均勻即可。,
#
# 1.先將蛋打進碗中，再將蕃茄切丁、九層塔也放入後加少許鹽攪拌,備用。,2.將平鍋倒入少許油加熱，將碗中材料倒入鍋中蓋上鍋蓋煎熟後掀,鍋蓋將蛋翻面煎熟既可上桌食用。,
#
# 1.先將乾香菇泡軟切丁、蒜頭切末備用。,2.備容器，將絞肉放入，再加入蒜末、香菇丁及少許地瓜粉及醬油調味後，用手攪拌均勻至黏稠狀備用即可。,3.備平鍋倒入少許油加熱，將肉餅擺入，再用鍋鏟壓平後，蓋上鍋蓋，轉小火煎烤至二面金黃既可盛盤食用。,
#
# 1.先將牛肉切滾刀、蒜頭切片、青椒切片備用。,2.備平鍋倒入少許油加熱、將蒜片、宮保先放入爆香，再將牛肉加入鍋中拌炒一下後蓋上鍋蓋燜煮一下既可。,3.起鍋前加入辣椒段，及少許糖、胡椒粉、酒、醬油及鹽調味拌勻後，再加入青椒及蒜味花生粒攪拌提味後既可盛盤上餐桌。,
#
# 1.先將綠竹筍、紅蘿蔔乾香菇全切丁備用。,2.將湯鍋加入水及少許酒、蔥段、薑片煮開，將海參入鍋川燙一下，取出切丁備用。,3.再將雞胸肉切丁加入少許太白粉、醬油、橄欖油攪拌入味備用。,
#
# 1.先將明蝦去頭去殼，用剪刀將背部剪開備用。,2.備平鍋倒入少許油加熱，將明蝦入鍋蓋上鍋蓋燜至熟再翻面，加少許薑末、蒜末、蔥末，再蓋上鍋蓋，關火後再燜1分鐘既可。,3.起鍋前再加少許辣椒醬、酒釀、酒、糖、鹽、胡椒粉調味及少許水、蔥花拌勻，即可盛盤上桌。,
#
# 1.山藥洗淨去皮切塊、排骨洗淨川燙備用。,2.燉鍋加入排骨、水半鍋、酒以中火煮滾，改成小火燉煮20分鐘。,3,打開鍋蓋加入山藥、枸杞再燉煮5分鐘即可。,
#
# 1.備湯鍋加入3/1水煮開，先將山藥丁、生山藥刨皮切丁入鍋中煮滾，再加入玉米醬煮開後，加入椰粉及冰糖調味燜煮一下既可。,2.起鍋時再將榴槤去仔切片擺入，即可盛盤上餐桌享受。,
#
# 1.先將乾香菇泡軟切丁、山藥去皮切條、薑切片、辣椒切段備用。,2.將蝦仁背劃刀，加少許太白粉、鹽調味，再加薑片、蔥段、辣椒段後備用。,3.備平鍋倒入少許油加熱，將所有材料全放入鍋中拌炒，再少許鹽、酒及胡椒粉調味拌炒後，即可盛盤上餐桌。,
#
# 土雞及金華火腿川燙備用。,鍋中加水煮滾，放入全雞、金華火腿、干貝、紅棗、枸杞、米酒，蓋上鍋蓋，以中火加熱至發出笛音聲，改小火燉12分鐘。,關火，關上氣閥，燜10分鐘，最後加入適量的塩即可。,
#
# 1.備小小鍋倒入少許橄欖油加熱，將豆鼓及辣椒、蒜頭、薑、蔥全切末入鍋爆香，再加少許醬油、胡椒粉、糖調味拌勻備用。,2.備平鍋加入七分滿的水煮開，再擺上蒸籠後，將鯧魚魚背劃刀淋上少許酒後擺入盤中，加入炒好的配料後入鍋中蓋上鍋蓋蒸十分鐘既可上餐桌。,
#
# 1.將原味蕃茄醬、橄欖油、檸檬汁、肉桂粉、丁香粉、胡椒粉、鹽混合製成沙拉醬。,2.義大利麵放入加鹽的滾水中煮12分鐘後取出瀝乾，淋上少許橄欖油拌勻備用，並將蝦仁、蘆筍過水燙熟。,3.將上述(2)材料混合後，加入鮪魚、小蕃茄及橄欖，並加鹽、大蒜精、黑胡椒調味。,4.生菜鋪於盤底，放入(3)之沙拉料及酪梨，最後淋上沙拉醬(1)。,
#
# 先將花椰菜放入加鹽的滾水中煮一分鐘，立即撈出並放入冷水中備用。,將義大利麵放入同一鍋滾水中煮10分鐘後取出瀝乾，淋上半匙橄欖油拌勻備用。,起油鍋(全功能健康平底鍋加入橄欖油，爆大蒜片，加入花椰菜、鹽水、黑胡椒粉、紅椒，起鍋備用。,蕃茄麵醬放入平底鍋煮沸後，加入義大利麵攪拌均勻，再盛於盤中，上面配上花椰菜。,最後將起士粉撒在義大利麵上，並佐紫蘇。,
#
# 入洋蔥丁炒香，將番苆、紅蘿蔔、馬鈴薯下鍋，加入所有的香料與水攪拌均勻。,塔吉鍋中火預熱，加入橄欖油、大蒜爆香後雞腿下鍋兩面微煎上色後起鍋備用。,蒜拍碎、洋蔥切丁、蕃茄切丁、紅蘿蔔、馬鈴薯切厚片、雞腿切塊。,將雞肉下鍋鋪在蔬菜上，蓋上鍋蓋小火悶煮30分鐘，最放加入綠橄欖悶煮10分鐘，起鍋前加入荷蘭芹即可。,
#
# 1.準備適量的油倒入湯鍋燒熱，蝦仁沾太白粉，(沾前，蝦仁的水先沾乾，避免有水)入油鐹炸，炸到金黃色撈起。,2.將A料調成糊狀，炸好的草蝦倒入拌勻。,3.水果罐頭內的水果鋪盤底，將拌好的蝦仁上，炒過的芝麻撒在上面即可。,
#
# 1.備羅伯鍋加入3/1水煮開，將雞肉塊放入鍋內川燙一下取出。,2.先將桂竹筍撕成片狀再切段待用。,3.備內鍋，將去骨雞腿切片、鹹冬切片、鮮香菇切片後，再將雞腿一片擺入再擺入鹹冬瓜片再擺入鮮香菇片(如此反覆擺上)既可，加入少許酒提味備用。,4.備快鍋加入3/1水煮開，將雞肉塊放入鍋中再將桂竹筍及鹹冬瓜全放入後，擺入三角架置上內鍋後蓋上鍋蓋，開中火煮至發出唧唧聲後轉小火煮3分鐘既可關火等排氣。,5.湯起鍋前加少許鹽調味既可上餐桌。,
#
# 1.先將鮭魚加入少許鹽及酒稍醃一下備用。,2.備平鍋倒入少許油加熱，將鮭魚用餐巾紙拭乾後放入鍋中煎至焦黃，再將魚身翻面煎至焦黃既可盛入盤中。,3.備小湯鍋，將紫蘇梅去子切碎放進鍋中，加少許水煮滾，再加入太白水芶芡既可。,4.將煮好的梅汁淋上盤中的鮭魚既可上餐桌。,
#
# 1.備羅伯鍋加入2/1水煮開，將皇宮菜切段放入川燙一下後先取出備用。,2.再將茄子切大段，全擺入鍋中再川燙一下取出備用。,3.將紫蘇梅去仔將果肉切碎，再將蒜頭、蔥、辣椒全切末後放入碗中攪拌均勻淋上蔬菜上既可上餐桌。,
#
# 明蝦處理過，放入平底鍋中煎熟，加入蒜末、蔥末、黑胡椒粒、鹽。,
#
# 1.處女蟹切塊，沾粉放入平底鍋中煎熟，灑點鹽、黑胡椒粒加入蔥花、蔥末、辣椒末、蒜末拌炒。,
#
# 1.備羅伯鍋加入3/1水煮開，將雞肉川燙一下後取出備用。,2.備內鍋，將胸肉切條放入，加入少許醬油、酒、糖,胡椒粉調味，再加入蒸肉粉攪拌調味備用。,3.備快鍋將椰汁全加入煮開(原汁全不加水)，放入雞肉、椰肉、參鬚、枸杞後，再加入少許酒調味，置入三腳架擺上內鍋再蓋上鍋蓋開中火煮開至發出唧唧聲後轉小火後煮5分鐘既可關火排氣，盛盤上餐桌。,
#
# 1.先將楊桃切條，將牛肉切條加入少許太白粉、醬油及沙拉油攪拌，再將薑切絲、蔥切段也加入備用。,2.備平鍋倒入少許油加熱，先將牛肉放入鍋中爆炒後，再加入楊桃入鍋中拌炒既可起鍋盛盤上餐桌。,
#
# 1.先將牛肉絲加入太白粉、醬油、蔥段、辣椒片攪拌調味稍醃一下備用。,2.備小湯鍋加入少許水煮開，將毛豆放入川燙一下取出備用。,3.將榨菜切絲備用。,4.備平鍋倒入少許油加熱，將牛肉絲放入鍋中拌炒幾下後既可起鍋待用，再將榨菜絲放入鍋中拌炒，加入少許水燜煮一下後再將炒好的牛肉放入，加入少許酒、糖拌炒調味，最後再將毛豆放進攪拌既可盛盤上餐桌。,
#
# 1.先將雞肉切絲加入太白粉及少許水攪拌，再將榨菜切絲、辣椒切絲、蔥切段備用。,2.備平鍋倒入少許油加熱，先將蔥段、辣椒絲、雞絲絲放入鍋中爆炒後，加入少許酒提味拌炒既可先起鍋備用。,3.再將平鍋加熱，放入榨菜絲及少許水後蓋上鍋蓋燜煮一下既可。,4.起鍋前再倒入雞絲拌炒入味既可盛盤上餐桌。,
#
# 1.先將鱈魚片加入鹽、酒稍醃一下入味備用。,2.將柳橙擠出橙汁待用。,3.備平鍋倒入2/1油加熱，將鱈魚沾上蛋汁及麵粉後放入鍋中炸至金黃後取出盛入盤中待用。,4.將平鍋中油倒出，再將橙汁倒入鍋中，加入少許鹽、糖及酒調味，再加入少許太白水勾芡後，再淋上魚片，切幾片柳橙擺飾既可上餐桌。,
#
# 1.鱈魚用鹽、酒稍微醃一下，沾蛋液，再沾麵粉，放入油鍋中炸。2.另起油鍋，倒入橙汁，灑點鹽、糖、酒稍微煮一下，欠薄芡，淋在1上灑點白芝麻。,
#
# 1.先將雞腿用刀，將筋剁一剁，加入醬油、糖稍醃一下備用。,2.備平鍋倒入少許油加熱，將紅蔥頭切片、薑片入鍋爆香，將雞腿肉朝下入鍋煎至金黃，再翻面煎至金黃。,3.起鍋前加少許水、醬油、檸檬汁調味後再蓋上鍋蓋燜入味至收湯汁既可盛盤上桌。,
#
# 1.先將肉切絲加入少許橄欖油、太白粉、蔥段拌勻備用。,2.將寧波年糕泡大約一小時。,3.備平鍋倒入少許油加熱，將肉絲入鍋爆香，再加入年糕、貢菜及少許水入鍋蓋上鍋蓋燜玉熟既可。,4.起鍋前再加少許鹽、胡椒粉調味既可盛盤上桌。,
#
# 1.先將水梨刨皮切片泡鹽水，紅、黃椒切條備用。,2.再將牛肉切片，加入蒜片、薑片、太白粉、醬油、沙拉油調味攪拌入味備用。,3.備平鍋倒入少許油加熱，將牛肉片放入爆炒，加入少許糖、醬油、酒調味，再將紅、黃椒全擺入拌炒，起鍋前再將水梨片放入攪拌一下既可上餐桌。,
#
# 1.將肉末、薑末、蝦皮、香油、醬油、鹽、水少許拌一拌再加冬粉、韭菜拌勻即可。,2.溫水一碗加入糖後續加入發酵粉使之溶解備用。,3.用一容器將麵粉倒入，續加入作法2用手揉成麵團用乾布蓋上(若麵團太乾可酌量加水)，揉至原來麵團的兩倍大即可用之。,4.將揉好的麵團分成一小塊，捍平，做成水煎包皮，再將做法1一小塊包入皮裏。,
#
# 在小湯鍋中，倒油後放入蒜末、沙茶醬、粉絲、豆腐、高湯，待煮滾，再放入蝦仁、蒜苗、米酒稍煮一下即可。,
#
# 長糯米洗淨瀝乾、蝦米洗淨泡軟、香菇泡軟切絲備用。,鍋中倒入油以中火爆香蝦米、香菇，待發出香味先將火關掉，再倒入長糯米及2杯水，加入油蔥酥、白胡椒粉、醬油拌勻，並將米粒整平，蓋上鍋蓋，中火煮至發出笛音聲改小火，計時5分鐘。,熄火，關上氣閥，燜15分鐘即可。,
#
# 1.先將什錦生菜洗淨，放入水和冰塊浸泡備用。,2.將調味料用打蛋器打勻混合即成為沙司。,3.將作法1洗淨的什錦生菜脫水，淋上2的沙司，散上白芝麻，即可食用。,
#
# 將貝類洗淨去沙。,辣椒、蒜仁切片、蕃茄切丁、九層塔切絲。,銅鍋倒入橄欖油放入蒜片直到蒜片變為金黃色，後放入大蛤蜊拌炒一下。,倒入白酒及蕃茄丁，蓋上鍋蓋直到收乾醬汁。,最後放入九層塔絲即可。,
#
# 將材料皆洗淨切好備用。,取一個鍋子先將配菜煮8分熟備用。,魚鍋中倒入半鍋水將材料紅蘿蔔,、洋蔥、西芹、白酒、黑胡椒粒、鹽及新鮮茴香放入鍋中，再將魚架放入（使食材不浮上來），蓋上鍋蓋煮至水滾。,再將魚放在魚架上，蓋上鍋蓋，再煮20分鐘後，打開鍋蓋放入剛已先煮好的配菜，再煮二分鐘，即可擺盤上桌。,
#
# 1.平底鍋加約半鍋的沙拉油燒熱，將土司泡於牛奶內。,2.將土司擠掉一些牛奶，再沾上太白粉放入平底鍋炸至呈金黃色後取出，撒上花生粉即可。,
#
# 1.先將牛肉切條，加入少許太白粉、醬油攪拌均勻入味，再將蒜頭切片、辣椒去仔切段、蔥切段全擺入後備用。,2.備平鍋倒入少許油加熱，將牛肉放入鍋中拌炒幾下，加入少許少許蠔油、糖、魚露、醬油、檸檬汁調味拌炒入味既可。,3.起鍋前再加入九層塔提味既可盛盤上餐桌。,
#
# 1.備平鍋，倒入麻油加熱再放入薑片爆香，將洋菇及紅棗放入鍋中拌炒，再將油豆腐切絲也加入鍋中後蓋上鍋蓋燜煮。,2.待煮滾後，掀鍋蓋放入少許鹽及酒調味既可直接上餐桌食用。,
#
# 1.先將紅蕃茄入滾水燙約10秒取出剝皮切片，洋菇切片備用。,2.備平鍋倒入少許油加熱，將蒜末、蔥段放入爆香後，加入肉末拌炒，再將洋菇、蕃茄全加入鍋中，加少許水後再蓋上鍋蓋燜煮至熟既可，起鍋前加入少許鹽調味，太白水芶芡既可上餐桌。,
#
# 1.洋蔥洗淨切絲、蔥淨切段、蒜頭剝皮、土雞腿切塊川燙後備用。,2.中火熱鍋，燉鍋放入橄欖油少許，放入洋蔥絲炒到軟，蔥、蒜爆香，加入雞腿略炒，再加入調味料，轉成小火蓋上鍋蓋悶1520分鐘即可。,
#
# 洋蔥、青椒切絲備用，中卷、蝦仁川燙好加一些塩及黑胡椒粒。,備一碗温水加入糖拌勻，再加入發酵粉等發酵粉溶解。,備清潔的調理盆倒入中筋麵粉將作法（2）慢慢加入麵粉中，揉成麵團蓋上保鮮膜靜待膨脹2倍大。,麵團加些麵粉，再揉至不粘手，抺上橄欖油將麵團桿平，約鍋子的大小。,以中火預熱，至水珠撒入成滾動狀，轉成小火，放入麵皮烤2分鐘翻面將火關掉。,在麵皮上塗上蕃茄醬、擺入洋蔥絲、青椒絲、中卷、蝦仁、蟹肉棒、黑胡椒粒最後再放入起司絲。,蓋上鍋蓋小火烤7分鐘即可。,
#
# 1.溫水1碗加入糖少許、醱粉1包，使之溶解備用。,2.用一容器將麵粉倒入，加入溶好的醱粉，溫牛奶250克、鹽少許和油少許，揉成麵團，用乾布蓋上（若麵團太乾，可酌量加水），醱酵至原來麵團的兩倍大即可。,3.鍋內倒少許油，捍好的麵粉圓餅鋪平，上加蕃茄糊續放A料，再灑些起司絲（胡椒粉可依個人喜好而加），蓋好鍋蓋，以小火烤58分鐘，起司絲溶化，餅熟即成一道美味可口披薩,
#
# 1.麵粉、地瓜粉、水充分攪拌成糊狀。2.鮭魚切丁，韭菜切丁，倒入平底鍋,中攤成圓形，煎至熟，可沾蕃茄醬吃。,
#
# 1.先將洋蔥切絲、小黃瓜切絲泡冰水備用。,2.備湯鍋加水煮開，將牛肉片放入川燙一下後取出泡冰水待用。,3.香菜切細段、小蕃茄切片、檸檬擠汁備用。,4.備大碗公，將牛肉片、黃瓜絲、洋蔥絲、蕃茄片、香菜段全加入後，加入金桔片、淋入檸檬汁及少許魚露、香油、白醋、鹽攪拌調味既可盛盤上餐桌。,
#
# 1.先將黃瓜、紅蘿蔔切絲泡冰水待用。,2.豆芽菜先川燙一下取出備用。,3.備碗公，將芝麻醬加入糖水、醋、香油、醬油攪拌調味既可。,4.備涼麵，再將黃瓜絲、紅蘿蔔絲、豆芽菜擺入，再淋入芝麻醬汁既成美味爽口的涼麵。,5.備湯鍋加入1/2水煮開，將豆腐切塊擺入，將川燙過的鮭魚頭加入，再擺入薑片後改蓋上鍋蓋煮滾既可。,6.最後將味噌加入少許水拌勻後倒入湯中，轉小火稍煮一下，起鍋時，再加入少許蔥花提味既可。,
#
# 1.淮山、芡實加水浸一小時，備用2.大魚頭斬開兩邊，洗淨抹乾水分3.,下少許油於Libra湯鍋後開火，待油熱後下薑塊及魚頭，將魚頭煎至焦黃4.,將已燒滾的八杯清水倒入鍋內，加入淮山、芡實5.,用小火燉一小時再下鹽調味即可,
#
# 平底鍋倒少許沙拉油熱鍋，將切好的絲瓜、放入鍋內，加入少許的水，蓋上鍋蓋，待鍋緣冒出水蒸氣時打開鍋蓋，加入調味料拌勻即可。,
#
# 起油鍋，爆香蒜片，待香味出來，放高麗菜心，蓋鍋蓋，待冒出水蒸氣，掀鍋蓋，放入辣椒絲，稍微拌炒一下，即可。,
#
# 1.平底鍋加入適量的水煮滾。,2.黃魚加入A料擺好，再加入調味料放於蒸盤(須用竹筷架空)。,3.將魚放進平底鍋蓋上鍋蓋蒸5~8分鐘，打開鍋蓋取出蒸盤，將魚換裝入另一盤中即可。,
#
# 1.先將土司泡水後取出擠乾撕碎加入牛絞肉及豬絞肉中，再將洋蔥切末也加入，加少許鹽及醬油及一顆蛋攪拌均勻，再用手揉搓均勻備用。,2.備平鍋倒入少許油加熱，將漢堡肉放入鍋中煎熟至焦狀，再翻面煎熟至焦狀既可取出備用。,3.再將漢堡包放入平鍋中乾烤約1分鐘既可。,4.將烤好的漢堡包放入肉片、洋蔥及蕃茄醬及胡椒粉既可食用。,
#
# 先將蘋果洗淨去皮切片、香蕉切片備用。,將奶油放在平底鍋開中火加熱使奶油融化後，放入切好的水果輕輕拌勻，加入白蘭地。,以點火器點著白蘭地及水果中的酒精成份，直到酒精蒸發，將使得水果中充滿豐富及多變的口感。,建議鍋具：單柄平底鍋,
#
# 1.先將肉切絲加入太白粉攪拌均勻，再將紅蘿蔔、木耳及筍全切絲，冬粉泡軟備用。,2.備平鍋倒入少許油加熱，先將蝦米爆香，再將肉司放入拌炒一下後再將紅蘿蔔絲、木耳及筍絲全擺入鍋中拌炒，再將冬粉全擺入後倒入高湯及水，少許醬油辣椒醬調味拌勻既可。B,3.起鍋後，再將少許胡椒粉及芹菜末、鹽調味拌炒既可盛盤上餐桌。,
#
# 1先將羅伯鍋加入3/1水燒開，將大豆苗放入川燙一下取出置入盤中做擺飾。,2.備平鍋，倒入少許油加熱將蒜頭切末、辣椒切絲放入鍋中爆香，後，加入辣豆瓣醬及少許高湯調味既可蓋上鍋蓋燜煮一下既可掀鍋蓋，再加入少許糖調味，再燜煮一下既可。,3.起鍋前灑少許胡椒粉既可置入盤中上餐桌食用。,
#
# 1.先將小卷洗淨擦乾、薑切細絲備用。,2.備平鍋加熱，放入薑絲爆香，再將小卷放入鍋中，蓋上鍋蓋燜煎約5分鐘後翻面，再燜煎一下既可起鍋盛盤。,
#
# 1.先將蝦仁少許鹽、太白粉攪拌入味備用。,2.將韭菜切段備用。,3.將平鍋倒入少許油燒熱，先將核桃放入鍋內拌炒至金黃後取出。,4.再將蝦仁放入鍋中拌炒，將薑切片也放入拌炒加入少許鹽、酒調,味再將韭菜放入拌炒。。,5.最後將核桃再倒入鍋中拌炒一下既可盛盤食用。,
#
# 1.平底鍋倒多一點的油燒熱（因為是1包米粉的量），把A料放入再擺上米粉。,2.蠔油與適量的水稀釋，倒入米粉上頭，蓋鍋蓋，待鍋緣冒水蒸氣，打開鍋蓋，放紅蘿蔔絲，灑些胡椒粉（如喜愛芹菜或香菜可放在米粉上），用筷子把鍋內所有材枓拌均勻即可。,用此平底鍋炒出來的米粉不油膩且味道與眾不同。,註：1包米粉1~2碗水。,
#
# 1.先將豬肉切絲、鮮香菇切片、蝦仁切片、韭菜切段、蝦米泡水洗淨備用。,2.備平鍋倒入少許油加熱，將肉絲先放入鍋中拌炒，再將蝦仁、蝦米、香菇全放入拌炒幾下，加入少許醬油、胡椒粉調味既可。,3.最後再將米苔目(2斤)全放入鍋中，再加入韭菜段拌炒均勻後,再加入少許水攪拌既可盛盤上餐桌。,
#
# 1.平底鍋加入少許油，將A料放入鍋內炒香。,2.再將羊肉片放入拌炒數下至羊肉變色即可，加入調味料拌勻即可。,
#
# 平底鍋中放入鹽、花生，稍微拌炒，蓋鍋蓋，悶烤一下，炒至熟。,
#
# 1.雞胸肉切丁，加入A料拌均勻。,2.湯鍋倒少許油燒熱，將火調小，雞丁入鍋略炒到變色後，加入調味料少許拌均勻，再加入青、紅椒，蓋上鍋蓋約1分鐘後打開鍋蓋拌一拌，起鍋前撒點米酒即可。,
#
# 起油鍋，將蔥末、薑末、辣椒末放入爆香，放入鳳螺，蓋鍋蓋煮至熟，加點鹽、米酒。,
#
# 1.大黃瓜切厚片，鮮香菇切絲。2.爆香蔥段，放入1料，加少許水，蓋鍋蓋，煮至熟放入蝦仁、鹽。,
#
# 1.年糕切粗條，用餛飩皮包好，放入油鍋中炸。,
#
# 1.鋁泊紙放入平底鍋鋪好，把魚頭放入鍋內刷上烤肉醬，蓋鍋以小火烤至5~7分鐘。,2.將魚頭翻面，再刷上橘子醬烤至1~2分鐘即可。,
#
# 1.備平底鍋擺滿鹽加熱，將九孔入鍋，蓋上鍋蓋燜烤約2分鐘既可。2.起鍋盛盤上桌，將哇沙米加少許醬油當沾醬既可享受美味。,
#
# 小土雞洗淨，將蔥切段塞在肚中再將蒜片、胡椒粉、塩、五香粉、米酒醃一個晚上（至少3小時）。,將雞放入鍋中蓋上鍋蓋，先開中火至鍋邊冒出蒸氣再改小火，烤25分鐘。,放入所喜愛及當季的蔬菜。,最後打開鍋蓋在全雞的表面塗上蠔油上色再烤10分鐘即可。,
#
# 將地瓜帶皮涮洗乾淨。,以中火預熱，至水珠撒入成滾動狀，轉成小火，放入地瓜烤15分鐘，翻面，再烤15分鐘，關火燜一下即可。,
#
# 1.備溫水（不可燙手）加入糖拌一下，倒入醱粉，不可攪拌，等醱酵倒入容器裡，再加入麵粉拌勻，用濕布稍蓋，待麵糰再次醱酵。（如要做與平底鍋一樣大小的餅，需一斤麵粉）,2.醱酵好的麵糰，再用手揉，使彈性更佳，聚一麵糰，用手捏成圓形，紅豆餡放入，將邊緣用手捏起（如包包子形狀），再用手排成圓形（與鍋面一樣大小），上面灑上芝麻。（也可兩面均灑）,3.放入平底鍋蓋上鍋蓋烤7分鐘後打開鍋蓋翻面，再烤7分鐘，（烤至兩面均呈非常漂亮之金黃色即可）。,註：乾烤大餅不須擺油、水。,
#
# 烏魚子浸泡米酒脫膜備用。,蒜苗斜切備用、蘋果切片泡過塩水備用。,以中火預熱，至水珠撒入成滾動狀，轉成小火，放入烏魚子蓋上鍋蓋烤1分鐘，翻面再烤1分鐘即可拿出來放涼切片。,將蘋果及蒜苗及切好的烏魚子一起搭配食用風味更好。,
#
# 秋刀魚先醃米酒塩約15分鐘。,燒烤鍋以中火預熱，至水珠撒入成滾動狀，轉成小火，再放入秋刀魚蓋上鍋蓋，有香味，魚已半熟翻面，第二面同樣出現香味黃色即可。,起鍋呈盤擠些新鮮檸檬汁及胡椒粉。,
#
# 1.先將羊排加入百里香、迷迭香香料及少許鹽和胡椒粉梢醃一下。,2.備平鍋，倒入少許橄欖油加熱後，將羊排放入蓋上鍋蓋煎至焦黃後，掀鍋蓋翻面再蓋上鍋蓋煎至焦黃既可起鍋盛入盤中。,3.再將洋菇放入鍋中，倒入白酒拌炒調味既可起鍋淋上羊排上。,4.最後再將紅蘿蔔、玉米、西芹放進盤中擺飾，既可上餐桌。,
#
# 1.將蛋打開，把蛋黃、蛋白分開備用。,2.把蛋放入不銹鋼盆中(勿用鋁盒)用打蛋器同一方向打，打到蛋白成泡能站立，加入糖攪拌至糖完全溶解均勻發亮。,3.先將蛋黃加入一匙沙拉油拌勻，倒入蛋白中，同一方向再拌到顏色均勻為止。,4.麵粉與香草粉過篩後加入３料中，用橡皮刀輕輕劃開至麵粉完全拌勻為止（切記用力攪拌）。,5.平底鍋預熱一分鐘，塗勻奶油，將已完成的材料，倒入鍋中攤平轉小火(最低火苗)約12分鐘，打開鍋蓋可用牙籤試(以不沾黏為原則)。,
#
# 1.先將德國豬腳大骨取出待用。,2.備湯鍋加入3/1水煮開，將大骨放入熬高湯，再將白菜撕大片,放入，乾香菇泡軟切半擺入，加入少許醬油調味，蓋上鍋蓋燜,煮至爛既可盛盤上餐桌。,3.備湯鍋倒入少許油加熱，將蒜末、辣椒末放入爆香，再將酸菜切末全放入拌炒入味既可備用。,4.備平鍋倒入少許油加熱，將德國豬腳攤平擺入鍋中，蓋上鍋蓋煎至焦黃，再翻面煎至焦黃既可。,5.將豬腳盛出切薄片擺盤，擺入酸菜末、酸豆既可上餐桌。,
#
# 1.先將雞腿去骨，加入少許醬油、酒、糖、蔥段調味稍醃一下備用。,2.備平鍋加熱(不加油)，將雞腿放入後蓋上鍋蓋，轉小火燜烤至金黃後，再翻面燜烤至金黃既可盛出。,3.將雞腿切塊擺盤，灑上白芝麻及小蕃茄，再擠入檸檬汁既成美味佳餚。,
#
# 1.備平鍋加熱轉小火後，將香腸一根根擺入鍋中煎熟既可。,2.香腸煎烤熟後取出切薄片盛入盤中待用。,3.將蘿蔔去皮切薄片，擺入大碗中加入鹽醃一下去味，再將醃好的蘿蔔用清水洗淨擠乾水份後，加入辣椒末及香油調味攪拌既可擺入盤中上桌食用。,
#
# 1.備平鍋加熱，鍋內擺滿鹽，將魚放入鍋中燜烤約5分鐘，再將,魚翻面再燜烤5分鐘既可起鍋盛入盤中，再擺上檸檬既可食用。,
#
# 將烤麩、A料放入平底鍋，加水（蓋過材料），蓋鍋蓋慢煮至熟，打開鍋蓋使湯汁稍收乾，再加調味料拌勻即可。,
#
# 1.備烤盤器具，將馬鈴薯去皮切薄片擺入盤中。,2.再將培根切絲爆炒後入盤中，再加入少許奶油及起司絲後備用。,3.備平鍋加入少水加，熱將烤盤擺入蓋上鍋蓋烤約十分鐘既可盛盤上餐桌享受。,
#
# 1.將羊排加入A料醃3~4小時入味。,2.平底鍋放少許油用中火加熱，放入羊排蓋鍋蓋煎至1~2分鐘，再翻面煎至焦黃色7~8分熟，放至盤中，可沾調味料食用。,
#
# 1.麵粉加水，攪拌成糊狀。2.馬鈴薯、紅蘿蔔刨成絲，放入1中，灑點糊椒粉。3.平底鍋中放入牛油，倒入2料，煎至熟。,
#
# 平底鍋倒少許油（可先開瓦斯燒稍微熱，不先熱鍋也可），鍋貼排放，加1/2杯的水，鍋蓋蓋上，開中火，待鍋緣冒出水蒸氣時，打開鍋蓋，水已乾了，用鏟子鏟鏟看，底部鍋貼呈焦黃色，即可起鍋。,
#
# 1.先將干貝泡水撕成絲，火腿、豆腐、鮮香菇切塊備用。,2.備平鍋倒入少許油加熱，將蔥切段入鍋中爆香，再將豆腐、香菇、火腿、干貝絲全放入鍋中燜煮，倒入高湯，加入少許醬油、胡椒粉後蓋上鍋蓋燜煮5分鐘既可。,3.起鍋前加入少許太白水芶芡收湯汁既可上餐桌食用,
#
# 1.先將牛絞肉加入辣椒末、蔥末、洋蔥末、蒜末及少許醬油、糖、蠔油、胡椒粉、酒調味拌勻備用。,2.備平鍋倒入少許油加熱，先將調味好的牛絞肉入鍋快炒後既可先盛盤備用。,3.再備平鍋將燒餅擺入鍋中烤熱取出，再包入牛肉末既可食用。（冷鍋擺入燒餅再開小火燜烤既可）,
#
# 1.先將雞腿切塊、金針泡軟打結、木耳切絲備用。,2.備平鍋倒入少許黑麻油加熱，將薑片放入爆香後，再加入蔥,段、蒜片暴香，再將雞塊加入鍋中後再蓋上鍋蓋燜煮既可。,3.起鍋前再加入金針、木耳及少許酒、蠔油、胡椒粉調味後再蓋上鍋蓋燜2分鐘，既可盛盤上餐桌。,
#
# 1.先將鬆餅粉加水攪拌成稠狀備用。,2.備平鍋加熱，將鬆餅粉倒入鍋中，用鍋鏟芶勻後，將鮪魚醬加入鋪開，洋蔥切末灑上後，加入胡椒粉及蕃茄醬調味後稍煎一下。,3.將鬆餅用鍋鏟慢慢捲起來後盛入盤中既可。,4.備湯鍋加入少許水加熱，將玉米醬倒入煮開後，再將蛋打散後倒入鍋中加入少許鹽調味既可成為美味可口的玉米濃湯。,
#
# 1.牛肉切片，加入醬油、沙拉油、太白粉拌均勻。,2.平底鍋倒少許油燒熱，放入蔥白、蒜片、牛肉片拌炒至牛肉變色(如溫度太高，可先熄火)，再倒入調味料及A料拌均勻，起鍋前撒點米酒即可。,
#
# 1.先將薑、皎白筍、辣椒切絲，蒜頭切片，紅蘿蔔去皮切絲備用。,2.將牛肉絲加入少許醬油、太白粉及薑絲、蒜片攪拌醃一下入味待用。,3.備平鍋倒入少許油加熱，將牛肉絲全放入鍋內爆炒至變色後，再放入蘿蔔絲及皎白筍絲，辣椒絲拌炒一下，加入少許糖及蠔油調味拌炒，待熟後即可起鍋盛盤上餐桌。,
#
# 1.先將牛蒡刨皮切細絲泡鹽水，薑切絲備用。,2.將牛肉切絲加入薑絲及少許太白粉、醬油、油調味攪拌稍醃一下。,3.備平鍋倒入少許油加熱，將調理好牛肉絲放入鍋中爆炒，再將牛蒡絲全加入鍋中，再加入少許水後蓋上鍋蓋燜煮至蒸氣冒出既可。,4.起鍋前加入少許鹽調味攪拌，既可盛入盤中，再灑上白芝麻上餐桌。,
#
# 1.將牛蒡去皮刨絲後置入鹽水中泡待用。,2.將雞腿切塊，薑切細絲備用。,3.備平鍋倒入少許油加熱，將雞腿放入鍋中拌炒，放入薑絲拌炒一下蓋上鍋蓋燜煮約2分鐘。,4.掀鍋蓋，將牛蒡絲放入鍋內再蓋上鍋蓋燜煮約3分鐘既可。,5.起鍋前再加入少許鹽及酒調味記可盛盤。,6.上餐桌時將芝麻撒上盤中，既成美味營養的年菜。,
#
# 1.備一湯鍋，煮好開水、倒入整罐玉米醬至鍋中.,2.將香菇、生菜、蝦仁切丁備用.,3.湯滾後加入毛豆、香菇、蝦仁、少許鹽、酒,蓋上鍋蓋煮3分鐘滾開勾芡.,4.加入生菜，起鍋前加少許胡椒粉即可.,
#
# 1.,雞去皮、去脂肪洗淨過水川燙,2.玉米去外皮及鬚，洗淨、切塊,3,甘筍洗淨去皮、切塊,4,將月光湯鍋燒滾放入清水12杯,5,放入雞、薑片用中火燉半小時後轉用小火燉1小時，加入玉米、甘筍再燉一小時，加鹽調味即可。,
#
# 1.先將綠蘆筍去皮切段備用。,2.備平鍋倒入少許油燒熱，先將蘆筍放入鍋內蓋上鍋蓋燜煮。,3.掀鍋蓋再將玉米醬倒入鍋中拌炒，待煮滾加入少許鹽、酒調,味既可盛盤食用。,
#
# 1.先將雞胸肉拍一拍先切薄片再切細絲，綠竹筍去老皮切絲待用。,2.備平鍋加入少許油加熱，將蔥切段放入鍋中爆香，再將竹筍絲放入鍋中拌炒一下，再將雞絲全放入鍋內拌炒，加少許水及鹽調味後蓋上鍋蓋燜煮至冒水氣既可。,3.起鍋前加入甜豆拌炒，加少許酒、胡椒醬拌炒入味既可上餐桌。,
#
# 1.先將菜心剝皮切大段備用。,2.備平鍋倒入高湯加熱，將菜心、白果入鍋後再加少許水、薑片蓋上鍋蓋燜煮至熟既可。,3.起鍋時再加少許鹽、酒提味及太白粉勺芡既可盛盤上桌。,
#
# 1.先將鱈魚切片，加入酒、鹽稍醃一下，裹上地瓜粉備用。,2.將木耳、紅蘿蔔、薑全切絲備用。,3.備平鍋倒入七分滿的油加熱，將魚片全入鍋炸至金黃後撈出盛盤備用。,4.備湯鍋加入少許水煮開，加入木耳絲、紅蘿蔔絲、白果、薑絲煮滾後，再加入少許醬油、糖、醋、胡椒粉調味，再加太白粉勾芡，再淋入魚片上既可上餐桌食用。,
#
# 1.大白菜剝下葉片洗淨切片、荸薺洗淨去皮後拍碎切末、蔥洗淨切末、薑洗淨去皮切末、蝦米泡軟、香菇泡軟5朵切碎、5朵切成對半備用。,2.豬絞肉放入大碗中，加入荸薺、香菇末、蔥末、薑末、太白粉、雞蛋、香油及米酒拌勻，分成適當大小後捏成圓球狀，放入熱油鍋中，以小火油炸至表面金黃，撈出瀝乾油分備用。,3,中火熱鍋倒入適量油燒熱，放入蝦米及切對半的香菇爆香，再加入大白菜、肉丸子與調味料塩、糖拌均煮滾後，改以小火加蓋燜煮約15分鐘即可。,
#
# 1.牛排加入調味料醃一下。,2.平底鍋倒少許油開中火燒，將醃好牛排入鍋煎至表面有點焦黃後取出備用。,3.快鍋不擺油、水，將煎好的牛排入鍋，倒入一瓶白酒，蓋上鍋蓋開中火煮滾發生唧唧聲，調小火計時30分鐘即可。,註：食用時取出切片，淋上原有的醬汁即可。,黑胡椒醬之
# 1.備羅伯(ROBOT)萬用妙鍋加入2/1水煮開，加入少許鹽，將義大利麵放入鍋中川燙約3分鐘既可關火取出待用。,2.將蒜頭切末、洋蔥切末、蕃茄切丁待用。,3.備全功能健康平底鍋加入少許橄欖油加熱，將蒜末、洋蔥末放入鍋中爆香，再將蛤蜊全倒入鍋中後轉小火蓋上鍋蓋燜煮至蛤蜊開。,4.倒入羅勒蕃茄麵醬煮開後，再加入少許白酒、鮮奶油、鹽調味。,5.最後將義大利麵全倒入鍋中攪拌均勻後，將九層塔切末加入提味拌勻即可。,6.起鍋時再加入蕃茄丁攪拌，加少,
#
# 將鹽和胡椒醃兩面里肌肉備用。,在銅鍋以中火預熱，直到水撒入時成為水珠狀跑動，這表示鍋子溫度已夠，即轉成小火。,在銅鍋中放入奶油和橄欖油，直到奶油開始沒有泡沫，然後變成稍微變棕色時，將里肌肉放入，煎致二面金黃。,煎好的里肌肉取出，用箔紙包起來保溫。,將鍋子移開火源，加入一半的白酒，攪拌使得醬汁味道入味，然後慢慢的攪拌使得醬汁在鍋內成褐色。,將鍋子回到火爐，加入洋蔥、磨菇片，煮2分鐘直到變成半透明。,加入大蒜煮一分鐘，要小心大蒜不要變焦，(不然會使得菜變的苦)。,加入剩餘的白酒，直到酒味蒸發，加入雞湯，煮67分鐘，待雞湯剩一半，之後加入鮮奶油，使得醬汁濃稠，可吸覆在湯匙上，將醬汁淋入肉片，即可上桌。,
#
# 1.備快鍋加入少許油加熱，將薑片放入爆香，再將鱸魚對切擺入鍋中煎至二面金黃。,2.另備湯鍋加入2/1水煮開後倒入快鍋中。,3.再將陳皮、淮山、百合、蜜棗等中藥材全擺入鍋中，將豬腱肉整塊也放入後，蓋上鍋蓋開中火煮開至發出唧唧聲後轉小火煮15分鐘既可關火排氣。,4.湯起鍋時再加入少許鹽、酒調味，既可盛盤上餐桌。,
#
# 1.烏參加A料川燙過，去細腸，斜切對半。,2.平底鍋內倒入百果、高湯、烏參、調味料(高湯淹蓋烏參)，蓋上鍋蓋，煮至烏參熟透，起鍋前太白粉調水勾芡，灑上胡椒粉，酒拌勻，即可。,
#
# 1.先將乾魷魚泡水待軟切絲、皎白筍、辣椒切絲、蒜頭切片備用。,2.備平鍋倒入少許油加熱，先將蒜片、辣椒絲、魷魚絲放入鍋中爆炒後，再放入皎白筍及少許水後蓋上鍋蓋燜煮約1分鐘既可。,3.起鍋前再加入少許醬油、胡椒粉、酒及糖調味既可盛盤上餐桌。,
#
# 1.銀芽先用湯鍋川燙撈起放在砂鍋裡，上鋪蒸好的魚翅。,2.用湯鍋加入調味料煮滾，加入太白粉調水溝芡，倒在魚,翅上，撒些金華火腿絲及香菜即可。,註：1.高湯取至於土雞燉湯之湯汁。,2.高湯可加入干貝及金華火腿，讓湯汁更加鮮美。,3.土雞燉湯必須加入蔥段、薑片。,
#
# 1.爆香紅蔥頭、肉末、蘿蔔乾。分別盛在碗中，放在平底鍋中隔水加熱，蒸20分鐘，將1料放在蒸好的碗粿上，淋點蠔油，即可。,
#
# 1.備小湯鍋加熱，將蛤蜊放入鍋內煮開，取出蛤蜊肉備用。,2.備平鍋倒入少許油加熱，將薑切片加入爆香，再將雞胸肉切絲放入鍋中拌炒一下後，再將小甜豆及蛤蜊肉加入燜煮一下既可。,3.起鍋前可加入少許酒及鹽調味，最後加入太白水芶芡收湯汁既可起鍋上餐桌。,
#
# 1.先將發粉加入溫水及少許糖發酵約5分鐘起泡既可，再倒入麵,粉內慢慢攪和再加入少許牛奶及鹽調味攪和至稠密狀後放至亮處醒麵約2小時既可。,2.再將醒好的麵糰用桿麵棍桿成比薩餅大小待用。,3.備平鍋倒入少許油後，再將比薩餅擺入鍋中，塗滿蕃茄糊，再將蕃茄切薄片、磨菇對切及草菇全擺上，再灑上起司絲，加入少許胡椒粉調味既可，蓋上鍋蓋，再開小火燜烤約5分鐘既可盛盤上餐桌。,
#
# 1.備羅伯鍋加入3/1水煮開，將紅甘魚頭放入川燙，再加入薑片及少許酒去味煮滾約1分鐘取出待用。,2.備快鍋加入2/1水加熱，將魚頭放入鍋中，再將綠竹筍去老皮切片福菜切段加入後蓋上鍋蓋開中火煮開至發出唧唧聲後轉小火煮5分鐘既可關火排氣。,3.起鍋倒入砂鍋內再開小火煮開，加入少許鹽及酒調味既可上餐桌。,
#
# 雞腿肉切塊川燙備用。,中空鍋中放入半鍋水，以中火煮滾加入雞腿、竹筍、薑片、塩。,蓋上鍋蓋，煮至發出笛音聲改小火，計時6分鐘，熄火，關上氣閥，燜10分鐘。,
#
# 1.先將雞胸肉切塊、淮山刨皮切塊，薑切片、鮮香菇切絲備用。,2.備平鍋倒入七分滿的水煮開，放上蒸籠，擺滿竹節盅後，將蛤蜊及所有材料放入盅中，加少許水及鹽調味後，蓋上鍋蓋煮約十五分鐘既可起鍋上餐桌。,
#
# 起油鍋放入薑絲、透抽、籚筍、紅蘿蔔、水蓋鍋蓋煮至熟，灑點鹽、酒。,
#
# 1.先將馬鈴薯刨皮切絲泡水，再將豬肉切絲加入少許太白粉、水、沙拉油攪拌，再擺上辣椒段及蔥段備用。,2.備平鍋倒入少許油加熱，先將肉絲入鍋中拌炒，再加入馬鈴薯絲及少許水後蓋上鍋蓋燜煮一下既可。,3.起鍋前再加入少許鹽、糖及醋調味既可盛盤上餐桌。,
#
# 1.先將麵粉加入水慢慢攪拌成麵糊備用。,2.將油條切段，再將芋頭刨皮切成條狀後塞入油條內再裹滿麵糊。,3.備湯鍋倒入七分滿的油加熱至約六分熱時，將油條入油鍋炸至金黃後撈出備用。,4.備平鍋倒入少許油加熱，將鳳梨、青椒、紅椒切丁入鍋，再加少許烏醋、糖、鳳梨汁調味，再將炸好的素排骨入鍋拌勻。,5.起鍋前加少許太白粉、醬油調味既可盛盤上桌。,
#
# 1.魚洗淨，用刀子由魚肚子剝開，不可切斷，翻開成一片，再用刀子在魚肉上縱橫劃成網狀。,2.平底鍋加入半鍋油，用中火燒熱，魚沾麵粉後放入鍋內炸至金黃色撈起。,3.小湯鍋放進調味料煮滾，加入太白粉調水勾芡，再淋些香油後倒入魚上，撒些A料即可。,
#
# 1.先將鱈魚加入少許酒、鹽梢醃一下後再沾上太白粉備用。,2.備平鍋倒入少許油加熱，將鱈魚放入乾煎，蓋上鍋蓋煎至金,黃，再翻面煎至金黃既可。,3.再將洋蔥切片、青椒切片，蒜頭切末全入鍋中拌炒入味，再加入少許少許烏醋、糖、酒、醬油及水調味後轉小火煮開既可。,4.起鍋前再加入鳳梨片燜一下既可上餐桌。,
#
# 1.平底鍋加入少許沙拉油以中小火燒熱，放入魚蓋鍋蓋煎3~5分鐘。,2.打開鍋蓋再翻面，同時加入（A料）蓋鍋蓋煎至1~2分鐘，再加入調味料煮至入味即可。,
#
# 1.小卷洗淨去除內臟備用。,2.在鍋中放入糖、醬油、米酒、蔥段、薑片、蒜頭、以中火煮滾，將小卷放入鍋中，在以小火煮6分鐘。,3,最後在打開鍋蓋時，用中火稍微收乾水分加入九層塔、淋上香油即可上桌。,
#
# 牛腩川燙洗淨備用、洋蔥切絲、蕃茄、紅蘿蔔切塊備用。,鍋中放入冰糖，中火加熱至冰糖溶化並先關火。,將牛腩放入拌至上色後先起鍋。,中空鍋倒入油爆香蔥段、洋蔥絲、辣豆瓣再放入牛腩、蕃茄、紅蘿蔔、蒜頭、薑片、醬油膏、米酒攪拌均勻，蓋上鍋蓋。以中火煮至發出笛音聲改小火，計時,25分鐘，關火，關上氣閥，燜10分鐘。,
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-28-c90b0dab2ca5> in <module>()
#      15 steps = []
#      16 for line in in_file.readlines():
# ---> 17     step = line.split("烹飪步驟,")[1]
#      18     print step
#      19     steps.append(step)
#
# IndexError: list index out of range

# %%
#菲姐- 試著二分法, 爬出來資料不完整, 因為網站code不乾淨
import requests
from bs4 import BeautifulSoup
page_format = "http://www.italian-lifestore.com.tw/recipe.php?SearchRecipeVideoCateID=&SearchKey=&SearchType1=&SearchType2=&Page=%d"

recipe_file = open("sis_recipe_list.txt", 'w')
for page in range(0,38): 
    recipe_list = requests.get(page_format%(page)) 
    recipe_response = recipe_list.text
    soup = BeautifulSoup(recipe_response)
    recipe_table = soup.select(".food")[0]
    recipe_rows = recipe_table.select('.clearfix')
    for recipe_row in recipe_rows:
        links = [tag['href'] for tag in recipe_row.select('a')] 
        link_href = "http://www.italian-lifestore.com.tw/" + links[0] 
        recipe_file.write(link_href + "\n") 
recipe_file.close()

#把每頁菜單的食材和步驟寫入
recipe_file = open("sis_recipe_list.txt", 'r')
for line in recipe_file.readlines(): 
    pagelink = line.strip() 
    request_get = requests.get(pagelink) 
    request_get.encoding = 'utf-8'
    soup = BeautifulSoup(request_get.text.encode('utf-8')) 
    try:
        if soup.find("ol") is not None:
            sis1_ingredients = open('sis1_ingredients.txt','a')
            sis1_steps = open('sis1_steps.txt','a')
            ingredientsList = [] 
            stepsList = []
            title = soup.select(".clearfix h3")[0].text.strip()
            ingredientsList.append(title)
            stepsList.append(title)
            ingredients = soup.select(".MsoNormal")[0].text.strip()
            for line in  ingredients.split('\n'):
                a = ''.join(line.split('-'))
                b = ','.join(a.split())
                ingredientsList.append(b)

            steps = soup.select("ol")[0].text.strip()
            c = ','.join(steps.split())
            stepsList.append(c)        

            for i in ingredientsList:
                sis1_ingredients.write((i+',').encode('utf-8')) 
            sis1_ingredients.write('\n')    
            for i in stepsList:
                sis1_steps.write((i+',').encode('utf-8')) 
            sis1_steps.write('\n')   

        else:
            sis2_ingredients = open('sis2_ingredients.txt','a')
            sis2_steps = open('sis2_steps.txt','a')
            ingredientsList = [] 
            stepsList = []
            title = soup.select(".clearfix h3")[0].text.strip()
            ingredientsList.append(title)
            stepsList.append(title)
            ingredients = soup.select(".mb20")[0].text.strip()
            a = ','.join(ingredients.split())
            ingredientsList.append(ingredients)
            seasioning = soup.select(".mb20")[1].text.strip()
            b = ','.join(seasioning.split())
            ingredientsList.append(b)

            steps = soup.select(".mb20")[2].text.strip()
            c = ','.join(steps.split())
            stepsList.append(c)        

            for i in ingredientsList:
                sis2_ingredients.write((i+',').encode('utf-8')) 
            sis2_ingredients.write('\n')    
            for i in stepsList:
                sis2_steps.write((i+',').encode('utf-8')) 
            sis2_steps.write('\n')   
    except:
        pass
sis1_steps.close()
sis1_ingredients.close()
sis2_steps.close()
sis2_ingredients.close()
recipe_file.close()
